# %% [markdown]
# # Fetch google trends and stock price data for the last 5 years.

# %% [markdown]
# ## Function to import trends data

# %%
import pandas as pd
from pytrends.request import TrendReq
import fix_yahoo_finance as yf  

def fetch_trend(stock_list, save_location):
    pytrend = TrendReq()
    
    for i in stock_list:
        kw_list = [i + " Stock"]
        
        pytrend.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='', gprop='')

        interest_over_time_df = pytrend.interest_over_time()
        interest_over_time_df['stock'] = i
        
        cl_name = i + " Stock"
        interest_over_time_df = interest_over_time_df.rename(columns={cl_name: 'gt_index'})
        interest_over_time_df.to_csv(save_location + i + "_gt.csv")

# %%
location = '/Users/jugalmarfatia/Documents/fall 2018/google_trends_stocks/Google-trends-stock-data/data/google_trends/'

df = pd.read_csv('/Users/jugalmarfatia/Documents/fall 2018/google_trends_stocks/Google-trends-stock-data/data/snp_500_companies_list.csv')

stocks = df['Symbol'].tolist()
fetch_trend(stocks, location)

# %% [markdown]
# ## Function to fetch yahoo finance data

# %%
def fetch_yf_data(stock_list, save_location):
    
    for i in stock_list:
        df = yf.download('AAPL','2013-09-23','2018-09-25')
        df['stock'] = i
        df.to_csv(save_location + i + "_price.csv")

# %%
stcok_location = '/Users/jugalmarfatia/Documents/fall 2018/google_trends_stocks/Google-trends-stock-data/data/stock_prices/'

fetch_yf_data(stocks, location)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# ...
